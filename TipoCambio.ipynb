# %%
import requests
import pandas as pd

# %% [markdown]
# <h1> Exchangegenerate <h1/>

# %%
ordenado2 = dict(sorted(data['rates'].items()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_58080/1377201297.py in <module>
# ----> 1 ordenado2 = dict(sorted(data['rates'].items()))
#
# NameError: name 'data' is not defined

# %%
response.headers['X-RateLimit-Remaining']

# %%
url_1 = 'https://api.exchangerate.host/timeseries?start_date=2020-01-01&end_date=2020-12-01'
response = requests.get(url_1, params ={'base':'USD'})
data = response.json()

# %%
len(data['rates'].keys())
# Out:
# 336

# %%
data
# Out:
# {'motd': {'msg': 'If you or your company use this project or like what we doing, please consider backing us so we can continue maintaining and evolving this project.',
#   'url': 'https://exchangerate.host/#/donate'},
#  'success': True,
#  'timeseries': True,
#  'base': 'USD',
#  'start_date': '2020-01-01',
#  'end_date': '2020-12-01',
#  'rates': {'2020-01-01': {'USD': 1,
#    'JPY': 108.697977,
#    'BGN': 1.736387,
#    'CZK': 22.634703,
#    'DKK': 6.662864,
#    'GBP': 0.754122,
#    'HUF': 294.558417,
#    'PLN': 3.806078,
#    'RON': 4.263167,
#    'SEK': 9.168078,
#    'CHF': 0.968898,
#    'ISK': 120.711167,
#    'NOK': 8.354247,
#    'HRK': 6.63301,
#    'RUB': 61.889493,
#    'TRY': 5.943766,
#    'AUD': 1.425274,
#    'BRL': 4.013279,
#    'CAD': 1.298458,
#    'CNY': 6.95045,
#    'HKD': 7.790215,
#    'IDR': 13686.034756,
#    'ILS': 3.44996,
#    'INR': 71.235184,
#    'KRW': 1153.979146,
#    'MXN': 18.920595,
#    'MYR': 4.021745,
#    'NZD': 1.484805,
# ...

# %%
df_1 = pd.DataFrame(data['rates']).T
df_1
# Out:
#             USD         JPY       BGN        CZK       DKK       GBP  \
# 2020-01-01  1.0  108.697977  1.736387  22.634703  6.662864  0.754122
# 2020-01-02  1.0  108.700651  1.736387  22.638980  6.657963  0.754478
# 2020-01-03  1.0  108.535494  1.743353  22.668875  6.688748  0.760451
# 2020-01-04  1.0  108.535494  1.743353  22.668875  6.688748  0.760451
# 2020-01-05  1.0  108.535494  1.743353  22.668875  6.688748  0.760451
# ...         ...         ...       ...        ...       ...       ...
# 2020-11-27  1.0  104.114988  1.635739  21.897399  6.220899  0.751512
# 2020-11-28  1.0  104.114994  1.635739  21.897401  6.220900  0.751513
# 2020-11-29  1.0  104.060559  1.634995  21.887990  6.219341  0.750323
# 2020-11-30  1.0  104.348863  1.639741  22.008994  6.238156  0.750241
# 2020-12-01  1.0  104.320179  1.622736  21.762091  6.166163  0.744795
#
#                    HUF       PLN       RON       SEK  ...            VES  \
# ...

# %%
response.headers['X-RateLimit-Remaining']
# Out:
# '1999'

# %%
df.round(4)
# Out:
#             USD       JPY     BGN      CZK     DKK     GBP       HUF     PLN  \
# 2020-01-01  1.0  108.6980  1.7364  22.6347  6.6629  0.7541  294.5584  3.8061
# 2020-01-02  1.0  108.7007  1.7364  22.6390  6.6580  0.7545  294.5424  3.7924
# 2020-01-03  1.0  108.5355  1.7434  22.6689  6.6887  0.7605  294.2064  3.7941
# 2020-01-04  1.0  108.5355  1.7434  22.6689  6.6887  0.7605  294.2064  3.7941
# 2020-01-05  1.0  108.5355  1.7434  22.6689  6.6887  0.7605  294.2064  3.7941
# ...         ...       ...     ...      ...     ...     ...       ...     ...
# 2020-11-27  1.0  104.1150  1.6357  21.8974  6.2209  0.7515  302.3100  3.7476
# 2020-11-28  1.0  104.1150  1.6357  21.8974  6.2209  0.7515  302.3100  3.7476
# 2020-11-29  1.0  104.0606  1.6350  21.8880  6.2193  0.7503  302.2110  3.7509
# 2020-11-30  1.0  104.3489  1.6397  22.0090  6.2382  0.7502  301.0817  3.7542
# 2020-12-01  1.0  104.3202  1.6227  21.7621  6.1662  0.7448  295.3873  3.6857
#
# ...

# %%
columnas_bien_1 = sorted(list(df_1.columns))

# %%
df_ordenado_1 = df_1[columnas_bien_1]
df_ordenado_1
# Out:
#                  AED        AFN         ALL         AMD       ANG         AOA  \
# 2020-01-01  3.668479  77.158898  106.434364         NaN       NaN         NaN
# 2020-01-02  3.668479  77.158898  106.434364         NaN       NaN         NaN
# 2020-01-03  3.670576  76.985051  106.445260         NaN       NaN         NaN
# 2020-01-04  3.670576  76.985051  106.445260         NaN       NaN         NaN
# 2020-01-05  3.670576  76.985051  106.445260         NaN       NaN         NaN
# ...              ...        ...         ...         ...       ...         ...
# 2020-11-27  3.673000  76.999999  103.649997  481.616213  1.794919  652.644980
# 2020-11-28  3.673001  77.000004  103.650003  481.616241  1.794920  652.645017
# 2020-11-29  3.673014  76.990264  103.784345  481.616036  1.794919  652.644739
# 2020-11-30  3.673021  77.049993  103.685039  481.616130  1.795336  654.816868
# 2020-12-01  3.672998  76.999970  103.475298  481.616030  1.795407  654.816732
#
# ...

# %%
pd.concat([df1,df2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23264/3314273901.py in <module>
# ----> 1 pd.concat([df1,df2])
#
# NameError: name 'df1' is not defined

# %%
url_2 = 'https://api.exchangerate.host/timeseries?start_date=2020-12-02&end_date=2021-12-31'
response_2 = requests.get(url_2, params ={'base':'USD'})
data_2 = response_2.json()

# %%
df_2 = pd.DataFrame(data_2['rates']).T
df_2
# Out:
#                  AED        AFN         ALL         AMD       ANG         AOA  \
# 2020-12-02  3.673001  76.950026  102.300038  481.616411  1.795836  654.817247
# 2020-12-03  3.672999  77.049982  102.131885  481.616061  1.795392  655.333773
# 2020-12-04  3.673000  76.950001  101.849997  481.616215  1.795043  653.564983
# 2020-12-05  3.673000  76.950001  101.849997  481.616215  1.795043  653.564983
# 2020-12-06  3.672982  76.955993  101.856411  481.616206  1.795044  653.564969
# ...              ...        ...         ...         ...       ...         ...
# 2021-11-28  3.671067  95.832291  107.212688  482.979439  1.801908  584.646201
# 2021-11-29  3.672559  96.175644  106.862483  483.153357  1.802231  574.634308
# 2021-11-30  3.673105  96.184654  106.821188  486.509527  1.794817  564.985986
# 2021-12-01  3.671093  95.905104  106.903524  486.327121  1.801419  564.837582
# 2021-12-02  3.673113  96.146312  106.873847  490.167126  1.803472  564.995149
#
# ...

# %%
columnas_bien_2 = sorted(list(df_2.columns))
df_ordenado_2 = df_2[columnas_bien_2]
df_ordenado_2
# Out:
#                  AED        AFN         ALL         AMD       ANG         AOA  \
# 2020-12-02  3.673001  76.950026  102.300038  481.616411  1.795836  654.817247
# 2020-12-03  3.672999  77.049982  102.131885  481.616061  1.795392  655.333773
# 2020-12-04  3.673000  76.950001  101.849997  481.616215  1.795043  653.564983
# 2020-12-05  3.673000  76.950001  101.849997  481.616215  1.795043  653.564983
# 2020-12-06  3.672982  76.955993  101.856411  481.616206  1.795044  653.564969
# ...              ...        ...         ...         ...       ...         ...
# 2021-11-28  3.671067  95.832291  107.212688  482.979439  1.801908  584.646201
# 2021-11-29  3.672559  96.175644  106.862483  483.153357  1.802231  574.634308
# 2021-11-30  3.673105  96.184654  106.821188  486.509527  1.794817  564.985986
# 2021-12-01  3.671093  95.905104  106.903524  486.327121  1.801419  564.837582
# 2021-12-02  3.673113  96.146312  106.873847  490.167126  1.803472  564.995149
#
# ...

# %%
url_3 = 'https://api.exchangerate.host/timeseries?start_date=2021-12-03&end_date=2022-05-24'
response_3 = requests.get(url_3, params ={'base':'USD'})
data_3 = response_3.json()

# %%
df_3 = pd.DataFrame(data_3['rates']).T
df_3
# Out:
#                  AED        AFN         ALL         AMD       ANG         AOA  \
# 2021-12-03  3.672497  96.125359  106.922810  490.982930  1.802431  564.853693
# 2021-12-04  3.673786  96.014157  106.902189  490.182376  1.801436  564.950201
# 2021-12-05  3.671165  96.037702  106.850202  489.908023  1.800460  564.634308
# 2021-12-06  3.673522  96.378411  107.125128  491.180526  1.802109  564.245020
# 2021-12-07  3.670291  96.374393  107.521988  492.381658  1.801742  563.763435
# ...              ...        ...         ...         ...       ...         ...
# 2022-05-20  3.671112  90.439428  113.522860  460.976128  1.803120  415.116092
# 2022-05-21  3.670479  90.429377  113.510571  460.924360  1.803094  415.070245
# 2022-05-22  3.669705  90.291581  113.357396  460.806718  1.802379  414.963492
# 2022-05-23  3.673733  90.588204  112.891320  455.828882  1.803673  416.407956
# 2022-05-24  3.670187  90.425510  112.443118  455.610655  1.802965  418.062386
#
# ...

# %%
columnas_bien_3 = sorted(list(df_3.columns))
df_ordenado_3 = df_3[columnas_bien_3]
df_ordenado_3
# Out:
#                  AED        AFN         ALL         AMD       ANG         AOA  \
# 2021-12-03  3.672497  96.125359  106.922810  490.982930  1.802431  564.853693
# 2021-12-04  3.673786  96.014157  106.902189  490.182376  1.801436  564.950201
# 2021-12-05  3.671165  96.037702  106.850202  489.908023  1.800460  564.634308
# 2021-12-06  3.673522  96.378411  107.125128  491.180526  1.802109  564.245020
# 2021-12-07  3.670291  96.374393  107.521988  492.381658  1.801742  563.763435
# ...              ...        ...         ...         ...       ...         ...
# 2022-05-20  3.671112  90.439428  113.522860  460.976128  1.803120  415.116092
# 2022-05-21  3.670479  90.429377  113.510571  460.924360  1.803094  415.070245
# 2022-05-22  3.669705  90.291581  113.357396  460.806718  1.802379  414.963492
# 2022-05-23  3.673733  90.588204  112.891320  455.828882  1.803673  416.407956
# 2022-05-24  3.670187  90.425510  112.443118  455.610655  1.802965  418.062386
#
# ...

# %%
url_0 = 'https://api.exchangerate.host/timeseries?start_date=2019-01-01&end_date=2019-12-31'
response_0 = requests.get(url_0, params ={'base':'USD'})
data_0 = response_0.json()

# %%
df_0 = pd.DataFrame(data_0['rates']).T
df_0
# Out:
#             USD         JPY       BGN        CZK       DKK       GBP  \
# 2019-01-01  1.0  109.614548  1.695206  22.336118  6.496302  0.785087
# 2019-01-02  1.0  109.657128  1.705898  22.435875  6.512912  0.783895
# 2019-01-03  1.0  107.440360  1.721682  22.739972  6.596660  0.798728
# 2019-01-04  1.0  107.799140  1.710737  22.506189  6.555351  0.791765
# 2019-01-05  1.0  107.799140  1.710737  22.506189  6.555351  0.791765
# ...         ...         ...       ...        ...       ...       ...
# 2019-12-27  1.0  109.611747  1.755157  22.918566  6.727232  0.769120
# 2019-12-28  1.0  109.611747  1.755157  22.918566  6.727232  0.769120
# 2019-12-29  1.0  109.611747  1.755157  22.918566  6.727232  0.769120
# 2019-12-30  1.0  109.458952  1.742354  22.737614  6.679306  0.763817
# 2019-12-31  1.0  108.900196  1.739243  22.667202  6.669166  0.762632
#
#                    HUF       PLN       RON       SEK  ...        UAH  \
# ...

# %%
columnas_bien_0 = sorted(list(df_0.columns))
df_ordenado_0 = df_0[columnas_bien_0]
df_ordenado_0
# Out:
#                  AED        AFN         ALL        ARS       AUD       BAM  \
# 2019-01-01  3.660576  74.662838  105.316279  37.560254  1.420169  1.693031
# 2019-01-02  3.670476  74.864771  105.601117  37.583319  1.418688  1.697609
# 2019-01-03  3.672115  75.720092  106.971196  37.763739  1.445485  1.719208
# 2019-01-04  3.673075  74.646651  106.206654  37.445352  1.427355  1.708191
# 2019-01-05  3.673075  74.646651  106.206654  37.445352  1.427355  1.708191
# ...              ...        ...         ...        ...       ...       ...
# 2019-12-27  3.582830  77.452482  107.278624  59.711017  1.439600  1.752815
# 2019-12-28  3.582830  77.452482  107.278624  59.711017  1.439600  1.752815
# 2019-12-29  3.582830  77.452482  107.278624  59.711017  1.439600  1.752815
# 2019-12-30  3.668932  77.115006  106.832409  59.783849  1.431944  1.740118
# 2019-12-31  3.672201  77.138011  106.472059  59.889305  1.428316  1.737011
#
# ...

# %%
df_tipo_cambio = pd.concat([df_ordenado_0, df_ordenado_1, df_ordenado_2, df_ordenado_3])

# %%
df_tipo_cambio.CLP
# Out:
# 2019-01-01    679.361350
# 2019-01-02    681.198744
# 2019-01-03    692.118749
# 2019-01-04    681.441489
# 2019-01-05    681.441489
#                  ...
# 2022-05-20    835.934117
# 2022-05-21    835.841084
# 2022-05-22    835.951317
# 2022-05-23    829.893194
# 2022-05-24    829.661001
# Name: CLP, Length: 1240, dtype: float64

# %%
df_tipo_cambio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1240 entries, 2019-01-01 to 2022-05-24
# Columns: 171 entries, AED to ZWL
# dtypes: float64(171)
# memory usage: 1.6+ MB

# %%
archivo_csv = df_tipo_cambio.to_csv(index=False)

# %%
df_tipo_cambio.to_csv('Proyecto-2-API/output.csv')
